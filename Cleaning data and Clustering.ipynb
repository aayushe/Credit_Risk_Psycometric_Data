# %% [markdown]
# ## load the dataset

# %%
import pandas as pd
credit_dataframe = pd.read_excel("database_credit.xlsx", sheet_name="Sheet1")

# %%
credit_dataframe
# Out:
#     Overall Serial No Country Specific Code All in BLOCK LETTER  \
# 0              LEGEND                   NaN                 NaN
# 1                 NaN                   NaN                 NaN
# 2              Sr. No                  Code                Name
# 3                   1                 IND-1      AMRINDER SINGH
# 4                   2                 IND-2               ANAND
# ..                ...                   ...                 ...
# 457               455               IND-455                 NaN
# 458               456               IND-456                 NaN
# 459               457               IND-457                 NaN
# 460               458               IND-458                 NaN
# 461               459               IND-459                 NaN
#
#     Use dd/mm/yyyy format    Name of Country                       Put U or R  \
# 0                     NaN                NaN                              NaN
# ...

# %%
credit_dataframe.shape
# Out:
# (462, 21)

# %%
credit_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 21 columns):
#  #   Column                                                                              Non-Null Count  Dtype
# ---  ------                                                                              --------------  -----
#  0   Overall Serial No                                                                   461 non-null    object
#  1   Country Specific Code                                                               460 non-null    object
#  2   All in BLOCK LETTER                                                                 145 non-null    object
#  3   Use dd/mm/yyyy format                                                               145 non-null    object
#  4   Name of Country                                                                     145 non-null    object
# ...

# %%
credit_dataframe.nunique()
# Out:
# Overall Serial No                                                                     461
# Country Specific Code                                                                 460
# All in BLOCK LETTER                                                                   145
# Use dd/mm/yyyy format                                                                  12
# Name of Country                                                                         2
# Put U or R                                                                              3
# in Years                                                                               28
# Put F or M                                                                              3
# Put L or I                                                                              2
# Mention e.g., Graduate/ Post Graduate etc.                                              3
# ...

# %% [markdown]
# ## drop columns with less than 86 records

# %%
def count_value(credit_dataframe, drop_columns):
    for column in credit_dataframe:
        if(credit_dataframe[[column]].count(axis=0)[0] < 87):
            drop_columns.append(column)
    return drop_columns

# %%
# def cal_len(column , credit_dataframe):
#     return credit_dataframe[[column]].count(axis = 0)[0]

# %%
drop_columns = []
drop_columns = count_value(credit_dataframe, drop_columns)
print("columns to drop are ", drop_columns)
for each in drop_columns:
    credit_dataframe.drop(each, axis=1, inplace=True)
# Out:
# columns to drop are  ['Put X or Y', 'Farmer (F)/ Proxy Sales Force: Dealer/ Retailer (PSF), Sales Staff (SS), Agent (A)', 'Put Y or N', 'Put Y or N.1']

# %%
credit_dataframe.columns
# Out:
# Index(['Overall Serial No', 'Country Specific Code', 'All in BLOCK LETTER',
#        'Use dd/mm/yyyy format', 'Name of Country', 'Put U or R', 'in Years',
#        'Put F or M', 'Put L or I',
#        'Mention e.g., Graduate/ Post Graduate etc.', 'Total No', 'In number',
#        'Put E or S', 'Total No of Years', 'Put H or O', 'Put Y or N.2',
#        'REMARKS'],
#       dtype='object')

# %%
credit_dataframe.head(5)
# Out:
#   Overall Serial No Country Specific Code All in BLOCK LETTER  \
# 0            LEGEND                   NaN                 NaN
# 1               NaN                   NaN                 NaN
# 2            Sr. No                  Code                Name
# 3                 1                 IND-1      AMRINDER SINGH
# 4                 2                 IND-2               ANAND
#
#   Use dd/mm/yyyy format    Name of Country                       Put U or R  \
# 0                   NaN                NaN                              NaN
# 1                   NaN                NaN                              NaN
# 2                  Date  Location: Country  Location: Urban (U) / Rural (R)
# 3   2019-06-11 00:00:00              INDIA                                U
# 4   2019-06-11 00:00:00              INDIA                                U
#
#   in Years                    Put F or M  \
# 0      NaN                           NaN
# 1      NaN                           NaN
# ...

# %%
# credit_dataframe.drop(credit_dataframe.index[0] , inplace=True)
# credit_dataframe.drop(credit_dataframe.index[1] , inplace=True)
# credit_dataframe.drop(credit_dataframe.index[2] , inplace=True)

# %%
credit_dataframe = credit_dataframe.drop(credit_dataframe.index[[0, 1, 2]])

# %%
credit_dataframe.reset_index()
# Out:
#      index Overall Serial No Country Specific Code All in BLOCK LETTER  \
# 0        3                 1                 IND-1      AMRINDER SINGH
# 1        4                 2                 IND-2               ANAND
# 2        5                 3                 IND-3        ANAND THAKUR
# 3        6                 4                 IND-4           ANANT LAL
# 4        7                 5                 IND-5        ANTIM JHAWAR
# ..     ...               ...                   ...                 ...
# 454    457               455               IND-455                 NaN
# 455    458               456               IND-456                 NaN
# 456    459               457               IND-457                 NaN
# 457    460               458               IND-458                 NaN
# 458    461               459               IND-459                 NaN
#
#     Use dd/mm/yyyy format Name of Country Put U or R in Years Put F or M  \
# ...

# %%
credit_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 459 entries, 3 to 461
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Overall Serial No                           459 non-null    object
#  1   Country Specific Code                       459 non-null    object
#  2   All in BLOCK LETTER                         144 non-null    object
#  3   Use dd/mm/yyyy format                       144 non-null    object
#  4   Name of Country                             144 non-null    object
#  5   Put U or R                                  144 non-null    object
#  6   in Years                                    86 non-null     object
#  7   Put F or M                                  144 non-null    object
#  8   Put L or I                                  119 non-null    object
#  9   Mention e.g., Graduate/ Post Graduate etc.  108 non-null    object
# ...

# %%
# credit_dataframe.drop(credit_dataframe.index[0] , inplace=True)

# %%
# credit_dataframe.reset_index()

# %%
credit_dataframe.head(4)
# Out:
#   Overall Serial No Country Specific Code All in BLOCK LETTER  \
# 3                 1                 IND-1      AMRINDER SINGH
# 4                 2                 IND-2               ANAND
# 5                 3                 IND-3        ANAND THAKUR
# 6                 4                 IND-4           ANANT LAL
#
#   Use dd/mm/yyyy format Name of Country Put U or R in Years Put F or M  \
# 3   2019-06-11 00:00:00           INDIA          U       33          M
# 4   2019-06-11 00:00:00           INDIA          U       30          M
# 5   2019-06-11 00:00:00           INDIA          U       31          M
# 6   2019-06-11 00:00:00           INDIA          U       35          M
#
#   Put L or I Mention e.g., Graduate/ Post Graduate etc. Total No In number  \
# 3          L                                   Graduate        4         2
# 4          L                                   Graduate        5         2
# ...

# %% [markdown]
# ### delete rows after 144

# %%
credit_dataframe = credit_dataframe.iloc[0:145, :]

# %%
credit_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 3 to 147
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Overall Serial No                           145 non-null    object
#  1   Country Specific Code                       145 non-null    object
#  2   All in BLOCK LETTER                         144 non-null    object
#  3   Use dd/mm/yyyy format                       144 non-null    object
#  4   Name of Country                             144 non-null    object
#  5   Put U or R                                  144 non-null    object
#  6   in Years                                    86 non-null     object
#  7   Put F or M                                  144 non-null    object
#  8   Put L or I                                  119 non-null    object
#  9   Mention e.g., Graduate/ Post Graduate etc.  108 non-null    object
# ...

# %%
credit_dataframe.columns
# Out:
# Index(['Overall Serial No', 'Country Specific Code', 'All in BLOCK LETTER',
#        'Use dd/mm/yyyy format', 'Name of Country', 'Put U or R', 'in Years',
#        'Put F or M', 'Put L or I',
#        'Mention e.g., Graduate/ Post Graduate etc.', 'Total No', 'In number',
#        'Put E or S', 'Total No of Years', 'Put H or O', 'Put Y or N.2',
#        'REMARKS'],
#       dtype='object')

# %%
# # Delete row at index position 0 & 1
# credit_dataframe = credit_dataframe.drop([credit_dataframe.index[144] ,credit_dataframe.index[459]])

# %%
credit_dataframe.shape
# Out:
# (145, 17)

# %% [markdown]
# ## remove all null value or Replace NAN rows

# %%
credit_dataframe
# Out:
#     Overall Serial No Country Specific Code All in BLOCK LETTER  \
# 3                   1                 IND-1      AMRINDER SINGH
# 4                   2                 IND-2               ANAND
# 5                   3                 IND-3        ANAND THAKUR
# 6                   4                 IND-4           ANANT LAL
# 7                   5                 IND-5        ANTIM JHAWAR
# ..                ...                   ...                 ...
# 143               141               IND-141        MANJU BISWAS
# 144               142               IND-142        ANUSUA MANNA
# 145               143               IND-143        RUPALI GUPTA
# 146               144               IND-144         BHABANI DAS
# 147               145               IND-145                 NaN
#
#     Use dd/mm/yyyy format Name of Country Put U or R in Years Put F or M  \
# 3     2019-06-11 00:00:00           INDIA          U       33          M
# ...

# %%
columns = credit_dataframe.columns
for col in columns:
    print("unique values in {} column is: {}". format(
        col, credit_dataframe[col].value_counts().size))
# Out:
# unique values in Overall Serial No column is: 145
# unique values in Country Specific Code column is: 145
# unique values in All in BLOCK LETTER column is: 144
# unique values in Use dd/mm/yyyy format column is: 11
# unique values in Name of Country column is: 1
# unique values in Put U or R column is: 2
# unique values in in Years column is: 27
# unique values in Put F or M column is: 2
# unique values in Put L or I column is: 1
# unique values in Mention e.g., Graduate/ Post Graduate etc. column is: 2
# unique values in Total No column is: 11
# unique values in In number column is: 7
# unique values in Put E or S column is: 2
# unique values in Total No of Years column is: 25
# unique values in Put H or O column is: 2
# unique values in Put Y or N.2 column is: 2
# unique values in REMARKS column is: 5

# %%
credit_dataframe[credit_dataframe.columns[1:]].describe()
# Out:
#        Country Specific Code All in BLOCK LETTER Use dd/mm/yyyy format  \
# count                    145                 144                   144
# unique                   145                 144                    11
# top                  IND-112       DEBATOSH DHAR   2019-06-11 00:00:00
# freq                       1                   1                    62
#
#        Name of Country Put U or R  in Years Put F or M Put L or I  \
# count              144        144        86        144        119
# unique               1          2        27          2          1
# top              INDIA          U        32          M          L
# freq               144        119         7        100        119
#
#        Mention e.g., Graduate/ Post Graduate etc.  Total No  In number  \
# count                                         108        86        143
# unique                                          2        11          7
# ...

# %% [markdown]
# ## rename columns

# %%
credit_dataframe.columns
# Out:
# Index(['Overall Serial No', 'Country Specific Code', 'All in BLOCK LETTER',
#        'Use dd/mm/yyyy format', 'Name of Country', 'Put U or R', 'in Years',
#        'Put F or M', 'Put L or I',
#        'Mention e.g., Graduate/ Post Graduate etc.', 'Total No', 'In number',
#        'Put E or S', 'Total No of Years', 'Put H or O', 'Put Y or N.2',
#        'REMARKS'],
#       dtype='object')

# %%
credit_dataframe.columns = ['serial_no', 'country_code', 'Name', 'Date', 'country_name', 'Urban_Rural', 'Age', 'Female_Male', 'Literate_Illiterate', 'Graduate_PG',
                            'Total_family_members', 'Dependent_family_member', 'Employed_Salaried', 'Years_of_Experience', 'Owns_House_Others', 'Married_Unmarried', 'REMARKS']

# %%
credit_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 3 to 147
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   serial_no                145 non-null    object
#  1   country_code             145 non-null    object
#  2   Name                     144 non-null    object
#  3   Date                     144 non-null    object
#  4   country_name             144 non-null    object
#  5   Urban_Rural              144 non-null    object
#  6   Age                      86 non-null     object
#  7   Female_Male              144 non-null    object
#  8   Literate_Illiterate      119 non-null    object
#  9   Graduate_PG              108 non-null    object
#  10  Total_family_members     86 non-null     object
#  11  Dependent_family_member  143 non-null    object
#  12  Employed_Salaried        126 non-null    object
#  13  Years_of_Experience      122 non-null    object
# ...

# %% [markdown]
# ## Fill missing Values

# %%
credit_dataframe.isna().sum()
# Out:
# serial_no                   0
# country_code                0
# Name                        1
# Date                        1
# country_name                1
# Urban_Rural                 1
# Age                        59
# Female_Male                 1
# Literate_Illiterate        26
# Graduate_PG                37
# Total_family_members       59
# Dependent_family_member     2
# Employed_Salaried          19
# Years_of_Experience        23
# Owns_House_Others          59
# Married_Unmarried          59
# REMARKS                     1
# dtype: int64

# %% [markdown]
# ### Fill age null value

# %%
credit_dataframe[credit_dataframe['Age'].isnull()]
# Out:
#     serial_no country_code                  Name        Date country_name  \
# 89         87       IND-87        SUMANTA MONDAL  23/08/2019        INDIA
# 90         88       IND-88   MD. JAHANGIR MONDAL  23/08/2019        INDIA
# 91         89       IND-89      ARUN KUMAR HAZRA  23/08/2019        INDIA
# 92         90       IND-90            SIRAJ OSTA  23/08/2019        INDIA
# 93         91       IND-91           RAJIB POALI  23/08/2019        INDIA
# 94         92       IND-92        TAPAS MAJUMDER  23/08/2019        INDIA
# 95         93       IND-93         KEYA KARMAKAR  23/08/2019        INDIA
# 96         94       IND-94       LALCHAND MONDAL  23/08/2019        INDIA
# 97         95       IND-95            NAMITA DAS  23/08/2019        INDIA
# 98         96       IND-96      PRATIMA BHOWMICK  23/08/2019        INDIA
# 99         97       IND-97          SUMAN MALLIK  23/08/2019        INDIA
# 100        98       IND-98     PUSPENDU ADHIKARI  23/08/2019        INDIA
# ...

# %%
print("min age ", credit_dataframe.Age.min())
print("max age ", credit_dataframe.Age.max())
print("mean Age", credit_dataframe.Age.mean())
print("median Age", credit_dataframe.Age.median())
print("mode Age", credit_dataframe.Age.mode())
# Out:
# min age  18
# max age  61
# mean Age 31.372093023255815
# median Age 32.0
# mode Age 0    18
# 1    32
# 2    34
# dtype: object

# %%
df_age = credit_dataframe.dropna(subset=['Age'], inplace=False)
df_age['Age'].value_counts().max()
df_age['Age'].value_counts().idxmax()
# Out:
# 32

# %%
credit_dataframe['Age'] = pd.to_numeric(
    credit_dataframe['Age'], errors='coerce')
credit_dataframe["Age"] = credit_dataframe["Age"].fillna(
    value=credit_dataframe["Age"].mean())

# %%
# frequency of occurance of values
import collections
collections.Counter(credit_dataframe.Age)
# Out:
# Counter({33.0: 5,
#          30.0: 4,
#          31.0: 6,
#          35.0: 4,
#          29.0: 3,
#          34.0: 7,
#          32.0: 7,
#          61.0: 1,
#          37.0: 2,
#          25.0: 1,
#          44.0: 2,
#          28.0: 1,
#          36.0: 5,
#          40.0: 4,
#          39.0: 5,
#          38.0: 2,
#          27.0: 2,
#          42.0: 2,
#          43.0: 1,
#          26.0: 1,
#          45.0: 1,
#          24.0: 2,
#          20.0: 3,
#          22.0: 3,
#          18.0: 7,
#          19.0: 3,
#          21.0: 2,
#          31.372093023255815: 59})

# %% [markdown]
# ### fill Literate_Illiterate null values

# %%
credit_dataframe[credit_dataframe['Literate_Illiterate'].isnull()]
# Out:
#     serial_no country_code                 Name        Date country_name  \
# 122       120      IND-120           JHUMA PAUL  22/08/2019        INDIA
# 123       121      IND-121           SUMITA DAS  22/08/2019        INDIA
# 124       122      IND-122        SAMAPTI KOLEY  22/08/2019        INDIA
# 125       123      IND-123      CHANDANA GHORUI  22/08/2019        INDIA
# 126       124      IND-124         SUPRIYA SHAW  22/08/2019        INDIA
# 127       125      IND-125    CHNADANA MAJUMDAR  22/08/2019        INDIA
# 128       126      IND-126           ARATI SHAW  22/08/2019        INDIA
# 129       127      IND-127           SOBHA SHAW  22/08/2019        INDIA
# 130       128      IND-128        MINATI HALDER  22/08/2019        INDIA
# 131       129      IND-129         MANJU GHORUI  22/08/2019        INDIA
# 132       130      IND-130        PRATIMA DALUI  22/08/2019        INDIA
# 133       131      IND-131            RITA SHAW  22/08/2019        INDIA
# ...

# %%
credit_dataframe.groupby(['Literate_Illiterate']).count()
# Out:
#                      serial_no  country_code  Name  Date  country_name  \
# Literate_Illiterate
# L                          119           119   119   119           119
#
#                      Urban_Rural  Age  Female_Male  Graduate_PG  \
# Literate_Illiterate
# L                            119  119          119          105
#
#                      Total_family_members  Dependent_family_member  \
# Literate_Illiterate
# L                                      86                      119
#
#                      Employed_Salaried  Years_of_Experience  \
# Literate_Illiterate
# L                                  101                  101
#
#                      Owns_House_Others  Married_Unmarried  REMARKS
# Literate_Illiterate
# L                                   86                 86      119

# %%
credit_dataframe["Literate_Illiterate"] = credit_dataframe["Literate_Illiterate"].fillna(
    "L")

# %%
credit_dataframe.groupby(['Literate_Illiterate']).count()
# Out:
#                      serial_no  country_code  Name  Date  country_name  \
# Literate_Illiterate
# L                          145           145   144   144           144
#
#                      Urban_Rural  Age  Female_Male  Graduate_PG  \
# Literate_Illiterate
# L                            144  145          144          108
#
#                      Total_family_members  Dependent_family_member  \
# Literate_Illiterate
# L                                      86                      143
#
#                      Employed_Salaried  Years_of_Experience  \
# Literate_Illiterate
# L                                  126                  122
#
#                      Owns_House_Others  Married_Unmarried  REMARKS
# Literate_Illiterate
# L                                   86                 86      144

# %% [markdown]
# ### Fill Graduate_PG null values

# %%
credit_dataframe[credit_dataframe['Graduate_PG'].isnull()]
# Out:
#     serial_no country_code                 Name                 Date  \
# 27         25       IND-25     MANJI BHAI PATEL  2019-06-11 00:00:00
# 63         61       IND-61                VIMAL  2019-06-11 00:00:00
# 76         74       IND-74     MADHUMITA MONDAL           19/10/2019
# 77         75       IND-75  MUZZAM ABUL HOSSAIN           19/10/2019
# 78         76       IND-76         NILAM KHUSBU           24/10/2019
# 79         77       IND-77           PRADIP DAS           19/10/2019
# 81         79       IND-79         SANDIP GHOSH           19/10/2019
# 82         80       IND-80        SHAHID AFRIDI           19/10/2019
# 83         81       IND-81           SIMRAN ROY           19/10/2019
# 85         83       IND-83         SRAYA BISWAS           24/10/2019
# 86         84       IND-84          SWAPNA SILL           19/10/2019
# 96         94       IND-94      LALCHAND MONDAL           23/08/2019
# 97         95       IND-95           NAMITA DAS           23/08/2019
# ...

# %%
credit_dataframe["Graduate_PG"].isna().sum()
# Out:
# 37

# %%
credit_dataframe["Graduate_PG"].isna().sum()
# Out:
# 37

# %%
credit_dataframe['Graduate_PG'].value_counts()
# Out:
# Graduate         62
# Post Graduate    46
# Name: Graduate_PG, dtype: int64

# %%
credit_dataframe["Graduate_PG"] = credit_dataframe["Graduate_PG"].fillna(
    "Graduate")

# %%
credit_dataframe['Graduate_PG'].value_counts()
# Out:
# Graduate         99
# Post Graduate    46
# Name: Graduate_PG, dtype: int64

# %% [markdown]
# ### Fill null values of Total_family_members

# %%
credit_dataframe['Total_family_members'].isna().sum()
# Out:
# 59

# %%
print("min Total_family_members ", credit_dataframe.Total_family_members.min())
print("max Total_family_members ", credit_dataframe.Total_family_members.max())
print("mean Total_family_members", credit_dataframe.Total_family_members.mean())
print("median Total_family_members",
      credit_dataframe.Total_family_members.median())
print("mode Total_family_members", credit_dataframe.Total_family_members.mode())
# Out:
# min Total_family_members  2
# max Total_family_members  12
# mean Total_family_members 4.813953488372093
# median Total_family_members 4.0
# mode Total_family_members 0    4
# dtype: object

# %%
credit_dataframe['Total_family_members'] = pd.to_numeric(
    credit_dataframe['Total_family_members'], errors='coerce')
credit_dataframe["Total_family_members"] = credit_dataframe["Total_family_members"].fillna(
    4)

# %%
credit_dataframe['Total_family_members'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Fill NAN Dependent_family_member values

# %%
credit_dataframe['Dependent_family_member'].isna().sum()
# Out:
# 2

# %%
print("min Dependent_family_member ",
      credit_dataframe.Dependent_family_member.min())
print("max Dependent_family_member ",
      credit_dataframe.Dependent_family_member.max())
print("mean Dependent_family_member",
      credit_dataframe.Dependent_family_member.mean())
print("median Dependent_family_member",
      credit_dataframe.Dependent_family_member.median())
print("mode Dependent_family_member",
      credit_dataframe.Dependent_family_member.mode())
# Out:
# min Dependent_family_member  0
# max Dependent_family_member  6
# mean Dependent_family_member 2.1538461538461537
# median Dependent_family_member 2.0
# mode Dependent_family_member 0    2
# dtype: object

# %%
credit_dataframe['Dependent_family_member'] = pd.to_numeric(
    credit_dataframe['Dependent_family_member'], errors='coerce')
credit_dataframe["Dependent_family_member"] = credit_dataframe["Dependent_family_member"].fillna(
    2)

# %%
credit_dataframe['Dependent_family_member'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Fill NAN Employed_Salaried

# %%
credit_dataframe['Employed_Salaried'].isna().sum()
# Out:
# 19

# %%
credit_dataframe['Employed_Salaried'].value_counts()
# Out:
# S                 101
# Retailer (PSF)     25
# Name: Employed_Salaried, dtype: int64

# %%
credit_dataframe["Employed_Salaried"] = credit_dataframe["Employed_Salaried"].fillna(
    "E")

# %%
credit_dataframe['Employed_Salaried'].value_counts()
# Out:
# S                 101
# Retailer (PSF)     25
# E                  19
# Name: Employed_Salaried, dtype: int64

# %% [markdown]
# ### Fill NAN values Years_of_Experience

# %%
credit_dataframe['Years_of_Experience'].isna().sum()
# Out:
# 23

# %%
print("min Years_of_Experience ", credit_dataframe.Years_of_Experience.min())
print("max Years_of_Experience ", credit_dataframe.Years_of_Experience.max())
print("mean Years_of_Experience", credit_dataframe.Years_of_Experience.mean())
print("median Years_of_Experience", credit_dataframe.Years_of_Experience.median())
print("mode Years_of_Experience", credit_dataframe.Years_of_Experience.mode())
# Out:
# min Years_of_Experience  0
# max Years_of_Experience  30
# mean Years_of_Experience 9.87295081967213
# median Years_of_Experience 10.0
# mode Years_of_Experience 0    10
# dtype: object

# %%
credit_dataframe['Years_of_Experience'] = pd.to_numeric(
    credit_dataframe['Years_of_Experience'], errors='coerce')
credit_dataframe["Years_of_Experience"] = credit_dataframe["Years_of_Experience"].fillna(
    10)

# %%
credit_dataframe['Years_of_Experience'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Fill NAN Owns_House_Others Values

# %%
credit_dataframe[credit_dataframe['Owns_House_Others'].isnull()]
# Out:
#     serial_no country_code                  Name        Date country_name  \
# 89         87       IND-87        SUMANTA MONDAL  23/08/2019        INDIA
# 90         88       IND-88   MD. JAHANGIR MONDAL  23/08/2019        INDIA
# 91         89       IND-89      ARUN KUMAR HAZRA  23/08/2019        INDIA
# 92         90       IND-90            SIRAJ OSTA  23/08/2019        INDIA
# 93         91       IND-91           RAJIB POALI  23/08/2019        INDIA
# 94         92       IND-92        TAPAS MAJUMDER  23/08/2019        INDIA
# 95         93       IND-93         KEYA KARMAKAR  23/08/2019        INDIA
# 96         94       IND-94       LALCHAND MONDAL  23/08/2019        INDIA
# 97         95       IND-95            NAMITA DAS  23/08/2019        INDIA
# 98         96       IND-96      PRATIMA BHOWMICK  23/08/2019        INDIA
# 99         97       IND-97          SUMAN MALLIK  23/08/2019        INDIA
# 100        98       IND-98     PUSPENDU ADHIKARI  23/08/2019        INDIA
# ...

# %%
credit_dataframe['Owns_House_Others'].isna().sum()
# Out:
# 59

# %%
credit_dataframe['Owns_House_Others'].value_counts()
# Out:
# H    53
# O    33
# Name: Owns_House_Others, dtype: int64

# %%
credit_dataframe["Owns_House_Others"] = credit_dataframe["Owns_House_Others"].fillna(
    "O")

# %%
credit_dataframe['Owns_House_Others'].value_counts()
# Out:
# O    92
# H    53
# Name: Owns_House_Others, dtype: int64

# %% [markdown]
# ### Fill NAN Married_Unmarried

# %%
credit_dataframe['Married_Unmarried'].isna().sum()
# Out:
# 59

# %%
credit_dataframe['Married_Unmarried'].value_counts()
# Out:
# Y    80
# N     6
# Name: Married_Unmarried, dtype: int64

# %%
credit_dataframe["Married_Unmarried"] = credit_dataframe["Married_Unmarried"].fillna(
    "Y")

# %%
credit_dataframe['Married_Unmarried'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Fill NAN REMARKS

# %%
credit_dataframe['REMARKS'].isna().sum()
# Out:
# 1

# %%
credit_dataframe['REMARKS'].value_counts()
# Out:
# ICA            66
# VFS-HO         33
# PSA-Online     20
# VFS-SINGUR     15
# VFS-ARIADAH    10
# Name: REMARKS, dtype: int64

# %%
credit_dataframe["REMARKS"] = credit_dataframe["REMARKS"].fillna("ICA")

# %%
credit_dataframe['REMARKS'].isna().sum()
# Out:
# 0

# %%
credit_dataframe.dropna(how='any', inplace=True)
# credit_dataframe_drop.isna().sum()

# %%
credit_dataframe.head(4)
# Out:
#   serial_no country_code            Name                 Date country_name  \
# 3         1        IND-1  AMRINDER SINGH  2019-06-11 00:00:00        INDIA
# 4         2        IND-2           ANAND  2019-06-11 00:00:00        INDIA
# 5         3        IND-3    ANAND THAKUR  2019-06-11 00:00:00        INDIA
# 6         4        IND-4       ANANT LAL  2019-06-11 00:00:00        INDIA
#
#   Urban_Rural   Age Female_Male Literate_Illiterate    Graduate_PG  \
# 3           U  33.0           M                   L       Graduate
# 4           U  30.0           M                   L       Graduate
# 5           U  31.0           M                   L  Post Graduate
# 6           U  35.0           M                   L  Post Graduate
#
#    Total_family_members  Dependent_family_member Employed_Salaried  \
# 3                   4.0                      2.0                 S
# 4                   5.0                      2.0                 S
# ...

# %% [markdown]
# ## chi square test for association of pair of columns

# %% [markdown]
# A small p-value (typically ≤ 0.05) indicates strong evidence against the null hypothesis, so you reject the null hypothesis.
#
# A large p-value (> 0.05) indicates weak evidence against the null hypothesis, so you fail to reject the null hypothesis.
#
# p-values very close to the cutoff (0.05) are considered to be marginal (could go either way). Always report the p-value so your readers can draw their own conclusions.

# %%
from scipy.stats import chi2_contingency
data_crosstab = pd.crosstab(credit_dataframe['REMARKS'],
                            credit_dataframe['Female_Male'],
                            margins=False)
print(data_crosstab)


# Get chi-square value , p-value, degrees of freedom, expected frequencies using the function chi2_contingency
stat, p, dof, expected = chi2_contingency(data_crosstab)

# select significance value
alpha = 0.05

# Determine whether to reject or keep your null hypothesis
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
    print('Variables are associated (reject H0)')
else:
    print('Variables are not associated(fail to reject H0)')
# Out:
# Female_Male   F   M
# REMARKS
# ICA           3  63
# PSA-Online   11   9
# VFS-ARIADAH  10   0
# VFS-HO        5  28
# VFS-SINGUR   15   0
# significance=0.050, p=0.000
# Variables are associated (reject H0)

# %% [markdown]
# ### chi square test for association one V/S all feature

# %%
# chiSquare test for dataframe :

import pandas as pd
import numpy as np
import scipy.stats as stats
from scipy.stats import chi2_contingency


class ChiSquare:
    def __init__(self, dataframe):

        self.df = dataframe
        self.p = None  # P-Value
        self.chi2 = None  # Chi Test Statistic
        self.dof = None

        self.dfTabular = None
        self.dfExpected = None

    def _print_chisquare_result(self, colX, alpha):
        result = ""
        if self.p < alpha:
            result = "{0} is IMPORTANT for Prediction".format(colX)
        else:
            result = "{0} is NOT an important predictor. (Discard {0} from model)".format(
                colX)
        print(result)

    def TestIndependence(self, colX, colY, alpha=0.05):
        X = self.df[colX].astype(str)
        Y = self.df[colY].astype(str)

        self.dfObserved = pd.crosstab(Y, X)
        chi2, p, dof, expected = stats.chi2_contingency(self.dfObserved.values)
        print("p value is ", p)
        self.p = p
        self.chi2 = chi2
        self.dof = dof

        self.dfExpected = pd.DataFrame(
            expected, columns=self.dfObserved.columns, index=self.dfObserved.index)

        self._print_chisquare_result(colX, alpha)

# %%
credit_dataframe.columns
# Out:
# Index(['serial_no', 'country_code', 'Name', 'Date', 'country_name',
#        'Urban_Rural', 'Age', 'Female_Male', 'Literate_Illiterate',
#        'Graduate_PG', 'Total_family_members', 'Dependent_family_member',
#        'Employed_Salaried', 'Years_of_Experience', 'Owns_House_Others',
#        'Married_Unmarried', 'REMARKS'],
#       dtype='object')

# %%
# Initialize ChiSquare Class
cT = ChiSquare(credit_dataframe)
# Feature Selection
testColumns = ['serial_no', 'country_code', 'Name', 'Date', 'country_name',
               'Urban_Rural', 'Age', 'Female_Male', 'Literate_Illiterate',
               'Graduate_PG', 'Total_family_members', 'Dependent_family_member',
               'Employed_Salaried', 'Years_of_Experience', 'Owns_House_Others',
               'Married_Unmarried']
for var in testColumns:
    cT.TestIndependence(colX=var, colY="REMARKS")
# Out:
# p value is  0.4452432881187898
# serial_no is NOT an important predictor. (Discard serial_no from model)
# p value is  0.4452432881187898
# country_code is NOT an important predictor. (Discard country_code from model)
# p value is  0.4452432881187898
# Name is NOT an important predictor. (Discard Name from model)
# p value is  3.9452901065354496e-96
# Date is IMPORTANT for Prediction
# p value is  1.0
# country_name is NOT an important predictor. (Discard country_name from model)
# p value is  3.9275358968153814e-30
# Urban_Rural is IMPORTANT for Prediction
# p value is  5.055555974882384e-17
# Age is IMPORTANT for Prediction
# p value is  5.2202149318472016e-18
# Female_Male is IMPORTANT for Prediction
# p value is  1.0
# Literate_Illiterate is NOT an important predictor. (Discard Literate_Illiterate from model)
# p value is  1.8266922291893095e-07
# Graduate_PG is IMPORTANT for Prediction
# p value is  2.5338372535521302e-05
# Total_family_members is IMPORTANT for Prediction
# ...

# %%
credit_dataframe.REMARKS.unique()
# Out:
# array(['ICA', 'PSA-Online', 'VFS-HO', 'VFS-SINGUR', 'VFS-ARIADAH'],
#       dtype=object)

# %% [markdown]
# ### make a copy of dataframe to analyse with behavioral dataset

# %%
# credit_dataframe.to_csv("Dataframe_cleaned.csv")

# %% [markdown]
# ##### Since date is unique we do not need that column as it might confuse the algorithm . also since country name is also same in all the columns we remove that too

# %%
credit_dataframe.columns
# Out:
# Index(['serial_no', 'country_code', 'Name', 'Date', 'country_name',
#        'Urban_Rural', 'Age', 'Female_Male', 'Literate_Illiterate',
#        'Graduate_PG', 'Total_family_members', 'Dependent_family_member',
#        'Employed_Salaried', 'Years_of_Experience', 'Owns_House_Others',
#        'Married_Unmarried', 'REMARKS'],
#       dtype='object')

# %%
credit_dataframe.drop(["Date", "country_code", "Name",
                       "country_name", "serial_no"], axis=1, inplace=True)

# %%
credit_dataframe.columns
# Out:
# Index(['Urban_Rural', 'Age', 'Female_Male', 'Literate_Illiterate',
#        'Graduate_PG', 'Total_family_members', 'Dependent_family_member',
#        'Employed_Salaried', 'Years_of_Experience', 'Owns_House_Others',
#        'Married_Unmarried', 'REMARKS'],
#       dtype='object')

# %%
credit_dataframe.head(4)
# Out:
#   Urban_Rural   Age Female_Male Literate_Illiterate    Graduate_PG  \
# 3           U  33.0           M                   L       Graduate
# 4           U  30.0           M                   L       Graduate
# 5           U  31.0           M                   L  Post Graduate
# 6           U  35.0           M                   L  Post Graduate
#
#    Total_family_members  Dependent_family_member Employed_Salaried  \
# 3                   4.0                      2.0                 S
# 4                   5.0                      2.0                 S
# 5                   3.0                      1.0                 S
# 6                   3.0                      1.0                 S
#
#    Years_of_Experience Owns_House_Others Married_Unmarried REMARKS
# 3                  5.0                 H                 Y     ICA
# 4                  7.0                 O                 Y     ICA
# 5                  7.0                 H                 Y     ICA
# ...

# %% [markdown]
# ### Convert categorical variable to dummy variables
# #### Dummy Variables for 16 columns. When drop_first is set as True, it gives k-1 dummies out of k categorical levels by removing the first level.

# %%
# num_cols = credit_dataframe.columns[credit_dataframe.dtypes.apply(lambda c: np.issubdtype(c, np.number))]
# num_cols

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
credit_dataframe[num_colsa] = scaler.fit_transform(credit_dataframe[num_cols])
credit_dataframe
# Out:
#     Urban_Rural        Age Female_Male Literate_Illiterate    Graduate_PG  \
# 3             U  33.000000           M                   L       Graduate
# 4             U  30.000000           M                   L       Graduate
# 5             U  31.000000           M                   L  Post Graduate
# 6             U  35.000000           M                   L  Post Graduate
# 7             U  29.000000           M                   L  Post Graduate
# ..          ...        ...         ...                 ...            ...
# 142           R  31.372093           F                   L       Graduate
# 143           R  31.372093           F                   L       Graduate
# 144           R  31.372093           F                   L       Graduate
# 145           R  31.372093           F                   L       Graduate
# 146           R  31.372093           F                   L       Graduate
#
#      Total_family_members  Dependent_family_member Employed_Salaried  \
# ...

# %%
credit_dataframe_dummies = pd.get_dummies(credit_dataframe, columns=[
                                          'Urban_Rural', 'Female_Male', 'Literate_Illiterate', 'Graduate_PG', 'Employed_Salaried', 'Owns_House_Others', 'Married_Unmarried', 'REMARKS'], drop_first=True)

# %%
credit_dataframe_dummies
# Out:
#            Age  Total_family_members  Dependent_family_member  \
# 3    33.000000                   4.0                      2.0
# 4    30.000000                   5.0                      2.0
# 5    31.000000                   3.0                      1.0
# 6    35.000000                   3.0                      1.0
# 7    29.000000                   6.0                      0.0
# ..         ...                   ...                      ...
# 142  31.372093                   4.0                      2.0
# 143  31.372093                   4.0                      2.0
# 144  31.372093                   4.0                      2.0
# 145  31.372093                   4.0                      3.0
# 146  31.372093                   4.0                      2.0
#
#      Years_of_Experience  Urban_Rural_U  Female_Male_M  \
# 3                    5.0              1              1
# 4                    7.0              1              1
# ...

# %%
credit_dataframe_dummies.to_csv("df_dummies.csv")

# %% [markdown]
# ##### K-Means Clustering

# %% [markdown]
# ##### PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
projected = pca.fit_transform(credit_dataframe_dummies)
print(credit_dataframe_dummies.shape)
print(projected.shape)
# Out:
# (144, 15)
# (144, 2)

# %% [markdown]
# ###### using elbow method to identify centroids

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
wcss = []
K = range(1, 15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(projected)
    wcss.append(km.inertia_)
plt.plot(K, wcss, 'bx-')
plt.xlabel('Number of centroids')
plt.ylabel('WCSS')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
# converting our projected array to pandas df
pca = pd.DataFrame(projected)
pca.columns = ['First component', 'Second Component']
# build our algorithm with k=3, train it on pca and make predictions
kmeans = KMeans(n_clusters=3, random_state=0).fit(pca)
y_kmeans = kmeans.predict(pca)
# plotting the results
plt.scatter(pca['First component'], pca['Second Component'],
            c=y_kmeans, s=50, alpha=0.5, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=50)
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=50)

# %% [markdown]
# #### K means method 2

# %%
# importing required libraries
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# defining the kmeans function with initialization as k-means++
kmeans = KMeans(n_clusters=2, init='k-means++')

# fitting the k means algorithm on scaled data
kmeans.fit(credit_dataframe_dummies)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# inertia on the fitted data
kmeans.inertia_
# Out:
# 672.471086074755

# %%
# fitting multiple k-means algorithms and storing the values in an empty list
SSE = []
for cluster in range(1, 20):
    kmeans = KMeans(n_jobs=-1, n_clusters=cluster, init='k-means++')
    kmeans.fit(credit_dataframe_dummies)
    SSE.append(kmeans.inertia_)

# converting the results into a dataframe and plotting them
frame = pd.DataFrame({'Cluster': range(1, 20), 'SSE': SSE})
plt.figure(figsize=(12, 6))
plt.plot(frame['Cluster'], frame['SSE'], marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %%
# k means using 5 clusters and k-means++ initialization
kmeans = KMeans(n_jobs=-1, n_clusters=5, init='k-means++')
kmeans.fit(credit_dataframe_dummies)
pred = kmeans.predict(credit_dataframe_dummies)

# %%
frame = pd.DataFrame(credit_dataframe_dummies)
frame['cluster'] = pred
frame['cluster'].value_counts()
# Out:
# 2    56
# 3    33
# 1    25
# 4    19
# 0    11
# Name: cluster, dtype: int64
